# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df_muliple_choice_reponses = pd.read_csv("multipleChoiceResponses.csv",encoding = "ISO-8859-1")
df_freeform = pd.read_csv("freeformResponses.csv")
df_Rates = pd.read_csv("conversionRates.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (31,83,86,87,98,99,109,116,123,124,127,129,130,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (5,17,21,38,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_muliple_choice_reponses.shape
# Out:
# (16716, 228)

# %%
df_freeform.shape
# Out:
# (16716, 62)

# %%
df_Rates.shape
# Out:
# (86, 3)

# %%
df_freeform
# Out:
#       GenderFreeForm    KaggleMotivationFreeForm      CurrentJobTitleFreeForm  \
# 0                NaN                         NaN                          NaN
# 1                NaN                         NaN                          NaN
# 2                NaN                         NaN                      teacher
# 3                NaN                         NaN                          NaN
# 4                NaN                         NaN                          NaN
# 5                NaN                         NaN                          NaN
# 6                NaN                         NaN                          NaN
# 7                NaN                         NaN                          NaN
# 8                NaN                         NaN                          NaN
# 9                NaN                         NaN                          NaN
# 10               NaN                         NaN                          NaN
# ...

# %%
# This Calculates the types of Status of the Employee
# employee_full_time,unemployee,freelancers = 0,0,0
a=np.array([0,0,0,0,0,0])
for i in range(len(df_muliple_choice_reponses)):
    if(df_muliple_choice_reponses['EmploymentStatus'].get_value(i) == 'Employed full-time'):
        a[0] += 1
    elif (df_muliple_choice_reponses['EmploymentStatus'].get_value(i) == 'Not employed, but looking for work'):
        a[1] +=1
    elif (df_muliple_choice_reponses['EmploymentStatus'].get_value(i) == 'Independent contractor, freelancer, or self-employed'):
        a[2] +=1
    elif(df_muliple_choice_reponses['EmploymentStatus'].get_value(i) == 'Not employed, and not looking for work'):
        a[3] +=1
    elif(df_muliple_choice_reponses['EmploymentStatus'].get_value(i) == 'Employed part-time'):
        a[4] +=1
    elif(df_muliple_choice_reponses['EmploymentStatus'].get_value(i) == 'I prefer not to say'):
        a[5] +=1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# ...

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
# 981

# %%
ls = []
for i in range(len(a)):
    ls.append(a[i])
    
ls
# Out:
# [10897, 2110, 1330, 924, 917, 420]

# %%
data = ['Employed full-time','Not employed, but looking for work','Independent contractor, freelancer, or self-employed','Not employed, and not looking for work','Employed part-time','I prefer not to say']
f,ax=plt.subplots(figsize=(18,8))
EmployementStatus=plt.bar(data,ls,align = "center")
plt.xticks(rotation = 90)
EmployementStatus[0].set_color('g')
EmployementStatus[1].set_color('r')
EmployementStatus[2].set_color('b')
EmployementStatus[4].set_color('y')
EmployementStatus[5].set_color('k')
plt.title('Employee Status')
ls
# Out:
# [10897, 2110, 1330, 924, 917, 420]

# %%
df_muliple_choice_reponses['Country']
# Out:
# 0                                NaN
# 1                      United States
# 2                             Canada
# 3                      United States
# 4                             Taiwan
# 5                             Brazil
# 6                      United States
# 7                              India
# 8                          Australia
# 9                             Russia
# 10                            Russia
# 11                             India
# 12                            Brazil
# 13                       Netherlands
# 14                            Taiwan
# 15                     United States
# 16                             Italy
# 17                    United Kingdom
# 18                     United States
# 19                            Brazil
# 20                     United States
# 21                     United States
# 22                     United States
# 23                    Czech Republic
# 24                     United States
# ...

# %%
df_muliple_choice_reponses['Country']
c_ar = np.array([0,0,0,0,0,0])
for i in range(len(df_muliple_choice_reponses)):
    if (df_muliple_choice_reponses['Country'].get_value(i) == "India"):
        c_ar[0] +=1
    elif(df_muliple_choice_reponses['Country'].get_value(i) == "Japan"):
        c_ar[1] +=1
    elif(df_muliple_choice_reponses['Country'].get_value(i) == "Australia"):
        c_ar[2] +=1
    elif(df_muliple_choice_reponses['Country'].get_value(i) == "United States"):
        c_ar[3] +=1
    elif(df_muliple_choice_reponses['Country'].get_value(i) == "Germany"):
        c_ar[4] +=1
    elif(df_muliple_choice_reponses['Country'].get_value(i) == "Russia"):
        c_ar[5] +=1
c_ar
c_ls = []
for i in range(len(c_ar)):
    c_ls.append(c_ar[i])
c_ls
labels = 'India','Japan','Australia','US','Germany','Russia'
explode = (0.3,0,0,0,0,0)
plt.pie(c_ls,labels = labels,explode = explode)
c_ls
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# ...

# %%
df_muliple_choice_reponses['StudentStatus']
stu = 0 
for i in range(len(df_muliple_choice_reponses)):
    if (df_muliple_choice_reponses['StudentStatus'].get_value(i) == "Yes"):
        stu += 1
NonStu = len(df_muliple_choice_reponses) - stu
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
# 15735

# %%
stu_nonStu = [stu,NonStu]
labels = 'students', 'Not Students'
explode = (0,0.7)
plt.pie(stu_nonStu,explode = explode,labels = labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x19785610940>,
# ...
#  [Text(1.0813574552222618, 0.2016582605182207, 'students'),
#   Text(-1.7694940446700214, -0.32998609952137137, 'Not Students')])

# %%
df_muliple_choice_reponses['CurrentJobTitleSelect']
# Out:
# 0                       DBA/Database Engineer
# 1                                         NaN
# 2                                         NaN
# 3            Operations Research Practitioner
# 4                          Computer Scientist
# 5                              Data Scientist
# 6                          Computer Scientist
# 7        Software Developer/Software Engineer
# 8                            Business Analyst
# 9        Software Developer/Software Engineer
# 10                                        NaN
# 11                             Data Scientist
# 12                                   Engineer
# 13                                        NaN
# 14       Software Developer/Software Engineer
# 15                      DBA/Database Engineer
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# ...

# %%
T_ar = np.array([0,0,0,0,0])
for i in range(len(df_muliple_choice_reponses)):
    if(df_muliple_choice_reponses['CurrentJobTitleSelect'].get_value(i) == "Data Scientist"):
        T_ar[0] +=1 
    elif(df_muliple_choice_reponses['CurrentJobTitleSelect'].get_value(i) == "Programmer"):
        T_ar[1] +=1 
    elif(df_muliple_choice_reponses['CurrentJobTitleSelect'].get_value(i) == "Software Developer/Software Engineer"):
        T_ar[2] +=1 
    elif(df_muliple_choice_reponses['CurrentJobTitleSelect'].get_value(i) == "Computer Scientist"):
        T_ar[3] +=1
    elif(df_muliple_choice_reponses['CurrentJobTitleSelect'].get_value(i) == "Data Analyst"):
        T_ar[4] +=1
#     else:
#         T_ar[5] +=1
        
T_ar
T_ls = []
for i in range(len(T_ar)):
    T_ls.append(T_ar[i])
T_ls
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# ...

# %%
data = ["Data Scientist","Programmer","Software Developer/Software Engineer","Computer Scientist","Data Analyst"]
f,ax=plt.subplots(figsize=(8,5))
EmployementStatus=plt.bar(data,T_ls,align = "center")
plt.xticks(rotation = 80)
# Out:
# ([0, 1, 2, 3, 4], <a list of 5 Text xticklabel objects>)

# %%
df_muliple_choice_reponses['LanguageRecommendationSelect']
# Out:
# 0              F#
# 1          Python
# 2               R
# 3          Python
# 4          Python
# 5          Python
# 6               R
# 7             SQL
# 8          Python
# 9          Python
# 10         Python
# 11         Python
# 12              R
# 13            NaN
# 14         Python
# 15              R
# 16            NaN
# 17            NaN
# 18         Python
# 19         Python
# 20           Java
# 21         Python
# 22         Matlab
# 23         Python
# 24         Matlab
# 25         Python
# 26              R
# 27         Python
# 28         Python
# 29       C/C++/C#
#            ...
# 16686         NaN
# 16687           R
# 16688         NaN
# 16689         NaN
# 16690         NaN
# 16691         NaN
# 16692         NaN
# 16693         NaN
# 16694         NaN
# 16695         NaN
# 16696         NaN
# 16697         NaN
# 16698         NaN
# 16699         NaN
# 16700         NaN
# 16701         NaN
# 16702         NaN
# 16703         NaN
# 16704      Python
# ...

# %%
T_ar = np.array([0,0,0,0,0])
for i in range(len(df_muliple_choice_reponses)):
    if(df_muliple_choice_reponses['LanguageRecommendationSelect'].get_value(i) == "Python"):
        T_ar[0] +=1 
    elif(df_muliple_choice_reponses['LanguageRecommendationSelect'].get_value(i) == "C/C++/C#"):
        T_ar[1] +=1 
    elif(df_muliple_choice_reponses['LanguageRecommendationSelect'].get_value(i) == "Java"):
        T_ar[2] +=1 
    elif(df_muliple_choice_reponses['LanguageRecommendationSelect'].get_value(i) == "R"):
        T_ar[3] +=1
    elif(df_muliple_choice_reponses['LanguageRecommendationSelect'].get_value(i) == "F#"):
        T_ar[4] +=1
#     else:
#         T_ar[5] +=1
        
T_ar
L_ls = []
for i in range(len(T_ar)):
    L_ls.append(T_ar[i])
L_ls
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# ...

# %%
L_ls.sort()
L_ls.reverse()
data = ["Python","Java","C/C++/C#","R","F#"]
f,ax=plt.subplots(figsize=(8,5))
EmployementStatus=plt.bar(data,L_ls,align = "center")
plt.xticks(rotation = 80)
L_ls
# Out:
# [6941, 2643, 307, 138, 4]

# %%
sns.pairplot(df_muliple_choice_reponses.head())
sns.distplot(df['column'])
sns.countplot(df['column'])
